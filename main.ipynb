# %% [markdown]
# <a href="https://colab.research.google.com/github/danielphilip12/San-Francisco-BART-Daily-Exits/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # import pandas library

# %%
df = pd.read_excel('/content/drive/MyDrive/Projects/San Francisco BART/data/Lab-SFBartDailyExits.xlsx') # imports excel file as dataframe
df.head() # displays first 5 rows of data
# Out:
#   \n🧪 Lab | SF BART Daily Exits
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
